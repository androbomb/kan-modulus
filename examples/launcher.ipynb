# %% [markdown]
# # 1. 1+1D Heat Equation

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    /envs/modulus/bin/python3 \
    ./heat.py \
    --config-name 'config_heat' \
    | tee -a ./logs/heat_logs.txt \
)
# Out:
# /envs/modulus/lib/python3.8/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [13:56:01] - JIT using the NVFuser TorchScript backend
# [13:56:01] - Disabling JIT because functorch does not work with it.
# [13:56:01] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# [13:56:01] - GraphManager: {'_func_arch': True, '_debug': False, '_func_arch_allow_partial_hessian': True}
# [13:56:02] - Arch Node: flow_network has been converted to a FuncArch node.
# [13:56:02] - Installed PyTorch version 2.0.1 is not TorchScript supported in Modulus. Version 1.14.0a0+410ce96 is officially supported.
# [13:56:02] - attempting to restore from: outputs/heat
# [13:56:02] - optimizer checkpoint not found
# ...

# %% [markdown]
# # Burgers Equation

# %%
!(export HYDRA_FULL_ERROR=1 && \
    export CUDA_LAUNCH_BLOCKING=1 && \
    /envs/modulus/bin/python3 \
    ./burgers.py \
    --config-name 'config_burgers' \
    | tee -a ./logs/burgers_logs.txt \
)
# Out:
# /envs/modulus/lib/python3.8/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [13:56:52] - JIT using the NVFuser TorchScript backend
# [13:56:52] - Disabling JIT because functorch does not work with it.
# [13:56:52] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# [13:56:52] - GraphManager: {'_func_arch': True, '_debug': False, '_func_arch_allow_partial_hessian': True}
# [13:56:52] - Arch Node: flow_network has been converted to a FuncArch node.
# [13:56:53] - Installed PyTorch version 2.0.1 is not TorchScript supported in Modulus. Version 1.14.0a0+410ce96 is officially supported.
# [13:56:53] - attempting to restore from: outputs/burgers
# [13:56:53] - optimizer checkpoint not found
# ...
